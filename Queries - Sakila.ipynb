# %% [markdown]
# # Shelly-Ann Duncan
# # 11/12/22
# # Queries - Sakila

# %%
# add the ERD

# %% [markdown]
# ![png](Data/ERD.png)

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
# create connection string using credentials
connection = f"mysql+pymysql://root:root@localhost/sakila"

# %%
# create engine
engine = create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %% [markdown]
# # Load data

# %%
q = """SHOW Tables;"""
pd.read_sql(q, engine)
# Out:
#               Tables_in_sakila
# 0                        actor
# 1                   actor_info
# 2                      address
# 3                     category
# 4                         city
# 5                      country
# 6                     customer
# 7                customer_list
# 8                         film
# 9                   film_actor
# 10               film_category
# 11                   film_list
# 12                   film_text
# 13                   inventory
# 14                    language
# 15  nicer_but_slower_film_list
# 16                     payment
# 17                      rental
# 18      sales_by_film_category
# 19              sales_by_store
# 20                       staff
# 21                  staff_list
# 22                       store

# %% [markdown]
# # Queries

# %%
# get all the customers inside city_id = 312. 
# query should return the customers' first name, last name, email, address, and city.
q = """SELECT customer.first_name, customer.last_name,
    customer.email, address.address, city.city_id
    FROM customer 
    JOIN address
    JOIN city
    ON customer.address_id = address.address_id
    WHERE address.city_id = 312"""
pd.read_sql(q, engine)
# Out:
#      first_name last_name                              email  \
# 0         CECIL     VINES     CECIL.VINES@sakilacustomer.org
# 1        MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org
# 2         CECIL     VINES     CECIL.VINES@sakilacustomer.org
# 3        MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org
# 4         CECIL     VINES     CECIL.VINES@sakilacustomer.org
# ...         ...       ...                                ...
# 1195     MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org
# 1196      CECIL     VINES     CECIL.VINES@sakilacustomer.org
# 1197     MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org
# 1198      CECIL     VINES     CECIL.VINES@sakilacustomer.org
# 1199     MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org
#
#                  address  city_id
# 0     548 Uruapan Street      251
# 1      1497 Yuzhou Drive      251
# 2     548 Uruapan Street       59
# 3      1497 Yuzhou Drive       59
# 4     548 Uruapan Street       63
# ...

# %%
# get all comedy films
# query should return film title, description, release year, rating, and special features
q1 = """SELECT film.title, film.description, film.release_year, film.rating, 
    film.special_features, category.name AS genre
    FROM film 
    JOIN film_category ON film.film_id = film_category.film_id
    JOIN category ON film_category.category_id = category.category_id 
    WHERE category.name = 'Comedy'"""
pd.read_sql(q1, engine)
# Out:
#                       title  \
# 0           AIRPLANE SIERRA
# 1               ANTHEM LUKE
# 2       BRINGING HYSTERICAL
# 3             CAPER MOTIONS
# 4             CAT CONEHEADS
# 5               CLOSER BANG
# 6    CONNECTION MICROCOSMOS
# 7            CONTROL ANTHEM
# 8                CRAZY HOME
# 9          DADDY PITTSBURGH
# 10             DOOM DANCING
# 11          DOWNHILL ENOUGH
# 12              DYING MAKER
# 13           ELEMENT FREDDY
# 14            FERRIS MOTHER
# 15    FIREBALL PHILADELPHIA
# 16    FLINTSTONES HAPPINESS
# 17    FRANKENSTEIN STRANGER
# 18        FREEDOM CLEOPATRA
# 19               GOLD RIVER
# 20          GROUNDHOG UNCUT
# 21            GUNFIGHT MOON
# 22            HATE HANDICAP
# 23           HEAVEN FREEDOM
# 24             HEDWIG ALTER
# 25         HURRICANE AFFAIR
# 26            HUSTLER PARTY
# 27               JAWS HARRY
# 28            KNOCK WARLOCK
# 29             LIFE TWISTED
# 30               LION UNCUT
# 31          LONELY ELEPHANT
# ...

# %%
# get all the films that Johnny Lollobrigida was in
# query should return the actor's last name, film title, and release year
q2 = """SELECT actor.last_name, film.title, film.release_year,
    FROM film
    JOIN last_name
    WHERE """

# %%
# all the actors in the movie titled "Bingo Talented"?
q3 = """SELECT *
    FROM 
    WHERE film = 'Bino Talented;'"""
pd.read_sql(q3, engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
# ...

# %%
# get the customer_id associated with all payments greater than twice the average payment amount?
# HINT: use 2* in your query to get twice the amount
# result should include the customer id and the amount

# %%
# list the first and last names of the 5 customers who have the highest number(count) of payments
# title the number of payments as num_payments.
